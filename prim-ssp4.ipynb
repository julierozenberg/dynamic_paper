# %%
# %load_ext autoreload
# %autoreload

from lib_for_prim import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = pd.read_csv("data_diversity_app2_ssp4.csv",sep=";")

# %%
data1.columns
# Out:
# Index(['leader productivity', 'productivity catch-up', 'fossil fuels',
#        'energy demand behaviors', 'energy efficiency', 'technologies',
#        'labor markets rigidities', 'adaptation indicator',
#        'mitigation indicator', 'ssp4'],
#       dtype='object')

# %%
experiments = data1[['leader productivity', 'productivity catch-up', 'fossil fuels',
       'energy demand behaviors', 'energy efficiency', 'technologies',
       'labor markets rigidities']]
outcomes=data1[["ssp4"]]
outcomes['un']=0+(data1["ssp4"]>0.)
# Out:
# C:\Miniconda3\lib\site-packages\IPython\kernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
forprim=format_data(outcomes,experiments,"un")

# %%
prim_obj   = prim.Prim(forprim, classify, mass_min = 0.01, threshold=.5)

# %%
box = prim_obj.find_box()
box.show_ppt()
plt.show()

# %%
box.inspect(4)
# Out:
# coverage    0.307692
# density     1.000000
# mass        0.112941
# mean        1.000000
# res dim     4.000000
# Name: 4, dtype: float64
#
#                         box 4
#                           min  max     qp values
# fossil fuels                0  1.0  2.520815e-14
# energy demand behaviors     0  0.5  4.365030e-02
# energy efficiency           0  1.5  6.433806e-02
# leader productivity         0  1.5  5.110235e-01

# %%
box.select(4)
box2 = prim_obj.find_box()
box2.show_ppt()
plt.show()

# %%
box2.inspect(5)
# Out:
# coverage    0.102564
# density     1.000000
# mass        0.037647
# mean        1.000000
# res dim     4.000000
# Name: 5, dtype: float64
#
#                       box 5
#                         min  max qp values
# energy efficiency         0  1.5         0
# fossil fuels              0  1.0         0
# productivity catch-up     0  1.5         0
# leader productivity       0  0.5         0

# %%
box2.select(5)
box3 = prim_obj.find_box()
box3.show_ppt()
plt.show()

# %%
box3.inspect(4)
# Out:
# coverage    0.102564
# density     1.000000
# mass        0.037647
# mean        1.000000
# res dim     4.000000
# Name: 4, dtype: float64
#
#                         box 4
#                           min  max qp values
# energy demand behaviors     0  0.5         0
# energy efficiency           0  1.5         0
# fossil fuels                0  1.0         0
# productivity catch-up       0  1.5         0

# %%
box3.select(4)
box4 = prim_obj.find_box()
box4.show_ppt()
plt.show()

# %%
box4.inspect(5)
# Out:
# coverage    0.070513
# density     1.000000
# mass        0.025882
# mean        1.000000
# res dim     4.000000
# Name: 5, dtype: float64
#
#                          box 5
#                            min  max qp values
# fossil fuels                 0  1.0  0.000355
# productivity catch-up        0  0.5  0.001468
# labor markets rigidities     0  0.5  0.014803
# leader productivity          0  1.5  0.016218

# %%
box4.select(5)
box5 = prim_obj.find_box()
box5.show_ppt()
plt.show()

# %%
box5.inspect(5)
# Out:
# coverage    0.038462
# density     1.000000
# mass        0.014118
# mean        1.000000
# res dim     4.000000
# Name: 5, dtype: float64
#
#                          box 5
#                            min  max qp values
# technologies                 0  0.5  0.001372
# energy efficiency            0  0.5  0.002581
# labor markets rigidities     0  0.5  0.006196
# fossil fuels                 0  1.0  0.011967

# %%
box5.select(5)
box6 = prim_obj.find_box()
box6.show_ppt()
plt.show()

# %%
box6.inspect(4)
# Out:
# coverage    0.051282
# density     1.000000
# mass        0.018824
# mean        1.000000
# res dim     4.000000
# Name: 4, dtype: float64
#
#                          box 4
#                            min  max qp values
# energy demand behaviors      0  0.5         0
# labor markets rigidities     0  0.5         0
# fossil fuels                 0  1.0         0
# leader productivity          0  1.5         0

# %%
box6.select(4)
box7 = prim_obj.find_box()
box7.show_ppt()
plt.show()

# %%
box7.inspect(3)
# Out:
# coverage    0.038462
# density     0.857143
# mass        0.016471
# mean        0.857143
# res dim     3.000000
# Name: 3, dtype: float64
#
#                         box 3
#                           min  max qp values
# fossil fuels                0  1.0  0.005123
# energy demand behaviors     0  0.5  0.056314
# energy efficiency           0  1.5  0.350286

# %%
box7.select(3)
box8 = prim_obj.find_box()
box8.show_ppt()
plt.show()

# %%
box8.inspect(5)
# Out:
# coverage    0.032051
# density     1.000000
# mass        0.011765
# mean        1.000000
# res dim     5.000000
# Name: 5, dtype: float64
#
#                       box 5
#                         min  max qp values
# fossil fuels              0  1.0  0.010951
# technologies              0  0.5  0.031250
# productivity catch-up     0  1.5  0.048283
# leader productivity       0  1.5  0.104358
# energy efficiency         0  1.5  0.185934

# %%
box8.select(5)
box9 = prim_obj.find_box()
box9.show_ppt()
plt.show()

# %%
box9.inspect(4)
# Out:
# coverage    0.051282
# density     0.888889
# mass        0.021176
# mean        0.888889
# res dim     3.000000
# Name: 4, dtype: float64
#
#                       box 4
#                         min  max qp values
# fossil fuels              0  1.0  0.002054
# productivity catch-up     0  0.5  0.019531
# leader productivity       0  1.5  0.036328

# %%
box9.select(4)
box10 = prim_obj.find_box()
box10.show_ppt()
plt.show()

# %%
box10.inspect(4)
# Out:
# coverage    0.038462
# density     0.857143
# mass        0.016471
# mean        0.857143
# res dim     4.000000
# Name: 4, dtype: float64
#
#                          box 4
#                            min  max qp values
# fossil fuels                 0  1.0  0.008374
# labor markets rigidities     0  0.5  0.009437
# energy efficiency            0  1.5  0.043380
# leader productivity          0  1.5  0.263374

# %%
box10.select(4)
box11 = prim_obj.find_box()
box11.show_ppt()
plt.show()

# %%
box11.inspect(4)
# Out:
# coverage    0.032051
# density     0.833333
# mass        0.014118
# mean        0.833333
# res dim     3.000000
# Name: 4, dtype: float64
#
#                       box 4
#                         min  max qp values
# productivity catch-up     0  0.5  0.006293
# fossil fuels              0  1.0  0.028909
# energy efficiency         0  1.5  0.077328

# %%
box11.select(4)
box12 = prim_obj.find_box()
box12.show_ppt()
plt.show()

# %%
box12.inspect(4)
# Out:
# coverage    0.032051
# density     0.833333
# mass        0.014118
# mean        0.833333
# res dim     4.000000
# Name: 4, dtype: float64
#
#                         box 4
#                           min  max qp values
# fossil fuels                0  1.0  0.005780
# energy demand behaviors     0  0.5  0.023195
# technologies                0  0.5  0.049188
# productivity catch-up       0  1.5  0.109375

# %%
box12.select(4)
box13 = prim_obj.find_box()
box13.show_ppt()
plt.show()

# %%
box13.inspect(4)
# Out:
# coverage    0.025641
# density     0.800000
# mass        0.011765
# mean        0.800000
# res dim     3.000000
# Name: 4, dtype: float64
#
#                     box 4
#                       min  max qp values
# fossil fuels            0  1.0  0.099148
# energy efficiency       0  0.5  0.119068
# leader productivity     0  1.5  0.135827

# %%
box13.select(4)
box14 = prim_obj.find_box()
box14.show_ppt()
plt.show()
