# %%
# %load_ext autoreload
# %autoreload

from lib_for_prim import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data1 = pd.read_csv("data_diversity_app1.csv")

# %%
experiments = data1[['leader productivity', 'productivity catch-up', 'fossil fuels',
       'energy demand behaviors', 'energy efficiency', 'technologies',
       'labor markets rigidities']]
outcomes=data1[["cumulated emissions"]]
outcomes['un']=0+(data1["cumulated emissions"]>2400)
# Out:
# C:\Miniconda3\lib\site-packages\IPython\kernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
forprim=format_data(outcomes,experiments,"un")

# %%
prim_obj   = prim.Prim(forprim, classify, mass_min = 0.01, threshold=.5)

# %%
box = prim_obj.find_box()
box.show_ppt()
plt.show()

# %%
box.inspect(5)
# Out:
# coverage    0.105263
# density     1.000000
# mass        0.015707
# mean        1.000000
# res dim     4.000000
# Name: 5, dtype: float64
#
#                         box 5
#                           min  max qp values
# technologies              0.0  0.5  0.000021
# leader productivity       1.5  2.0  0.000021
# fossil fuels              1.0  2.0  0.000138
# energy demand behaviors   0.0  0.5  0.003590

# %%
box.select(5)
box2 = prim_obj.find_box()
box2.show_ppt()
plt.show()

# %%
box2.inspect(4)
# Out:
# coverage    0.087719
# density     0.833333
# mass        0.015707
# mean        0.833333
# res dim     3.000000
# Name: 4, dtype: float64
#
#                         box 4
#                           min  max qp values
# fossil fuels              1.0  2.0  0.000927
# leader productivity       1.5  2.0  0.004101
# energy demand behaviors   0.0  0.5  0.036644

# %%
box2.select(4)
box3 = prim_obj.find_box()
box3.show_ppt()
plt.show()

# %%
box3.inspect(5)
# Out:
# coverage    0.140351
# density     0.666667
# mass        0.031414
# mean        0.666667
# res dim     5.000000
# Name: 5, dtype: float64
#
#                         box 5
#                           min  max qp values
# fossil fuels              1.0  2.0  0.000062
# energy demand behaviors   0.0  0.5  0.001226
# productivity catch-up     0.0  1.5  0.001226
# technologies              0.0  0.5  0.002782
# leader productivity       0.5  2.0  0.007879

# %%
box3.select(5)
box4 = prim_obj.find_box()
box4.show_ppt()
plt.show()

# %%
box4.inspect(6)
# Out:
# coverage    0.105263
# density     1.000000
# mass        0.015707
# mean        1.000000
# res dim     5.000000
# Name: 6, dtype: float64
#
#                         box 6
#                           min  max qp values
# energy demand behaviors   0.0  0.5  0.000003
# leader productivity       0.5  2.0  0.000021
# fossil fuels              1.0  2.0  0.000097
# technologies              0.5  1.0  0.000244
# energy efficiency         0.0  0.5  0.000459

# %%
box4.select(6)
box5 = prim_obj.find_box()
box5.show_ppt()
plt.show()

# %%
box5.inspect(6)
# Out:
# coverage    0.087719
# density     1.000000
# mass        0.013089
# mean        1.000000
# res dim     4.000000
# Name: 6, dtype: float64
#
#                     box 6
#                       min  max qp values
# leader productivity   1.5  2.0  0.000105
# energy efficiency     0.0  0.5  0.000171
# technologies          0.0  0.5  0.000199
# fossil fuels          1.0  2.0  0.004115

# %%
box5.select(6)
box6 = prim_obj.find_box()
box6.show_ppt()
plt.show()
